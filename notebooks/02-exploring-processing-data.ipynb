# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Import

# %%
data_path = os.path.join(os.path.pardir, 'data/raw/')
train_path = data_path + 'train.csv'
test_path = data_path + 'test.csv'

# %%
train_df = pd.read_csv(train_path, index_col='PassengerId')
test_df = pd.read_csv(test_path, index_col='PassengerId')

# %%
type(train_df)
train_df.info()
test_df.info()
train_df.head(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Name      418 non-null    object
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      417 non-null    float64
#  8   Cabin     91 non-null     object
#  9   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#              Parch     Ticket  Fare Cabin Embarked
# PassengerId
# 1                0  A/5 21171  7.25   NaN        S

# %% [markdown]
# ### Edit Data

# %%
test_df['Survived'] = -1

# %%
df = pd.concat((train_df, test_df))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1309 non-null   int64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1046 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Ticket    1309 non-null   object
#  8   Fare      1308 non-null   float64
#  9   Cabin     295 non-null    object
#  10  Embarked  1307 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB

# %%
df.tail()
# Out:
#              Survived  Pclass                          Name     Sex   Age  \
# PassengerId
# 1305               -1       3            Spector, Mr. Woolf    male   NaN
# 1306               -1       1  Oliva y Ocana, Dona. Fermina  female  39.0
# 1307               -1       3  Saether, Mr. Simon Sivertsen    male  38.5
# 1308               -1       3           Ware, Mr. Frederick    male   NaN
# 1309               -1       3      Peter, Master. Michael J    male   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C

# %%
df[['Name', 'Age']][:2]
# Out:
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0

# %%
df.loc[5:7, ['Age','Parch']]
# Out:
#               Age  Parch
# PassengerId
# 5            35.0      0
# 6             NaN      0
# 7            54.0      0

# %%
df[5:7][['Age', 'Fare']]
# Out:
#               Age     Fare
# PassengerId
# 6             NaN   8.4583
# 7            54.0  51.8625

# %% [markdown]
# ## Filter

# %%
df.loc[((df.Sex == 'male') & (df.Age == 22))]
# Out:
#              Survived  Pclass                               Name   Sex   Age  \
# PassengerId
# 1                   0       3            Braund, Mr. Owen Harris  male  22.0
# 61                  0       3              Sirayanian, Mr. Orsen  male  22.0
# 81                  0       3               Waelens, Mr. Achille  male  22.0
# 113                 0       3             Barton, Mr. David John  male  22.0
# 213                 0       3             Perkin, Mr. John Henry  male  22.0
# 226                 0       3       Berglund, Mr. Karl Ivar Sven  male  22.0
# 244                 0       3      Maenpaa, Mr. Matti Alexanteri  male  22.0
# 288                 0       3               Naidenoff, Mr. Penko  male  22.0
# 321                 0       3                 Dennis, Mr. Samuel  male  22.0
# 374                 0       1                Ringhini, Mr. Sante  male  22.0
# 396                 0       3                Johansson, Mr. Erik  male  22.0
# 479                 0       3          Karlsson, Mr. Nils August  male  22.0
# 522                 0       3                    Vovk, Mr. Janko  male  22.0
# 554                 1       3  Leeni, Mr. Fahim ("Philip Zenni")  male  22.0
# 589                 0       3              Gilinski, Mr. Eliezer  male  22.0
# 1018               -1       3           Brobeck, Mr. Karl Rudolf  male  22.0
# 1039               -1       3                   Davies, Mr. Evan  male  22.0
# 1171               -1       2          Oxenham, Mr. Percy Thomas  male  22.0
# 1203               -1       3               Vartanian, Mr. David  male  22.0
# 1211               -1       2       Jefferys, Mr. Ernest Wilfred  male  22.0
# 1290               -1       3     Larsson-Rondberg, Mr. Edvard A  male  22.0
#
#              SibSp  Parch             Ticket      Fare Cabin Embarked
# PassengerId
# 1                1      0          A/5 21171    7.2500   NaN        S
# 61               0      0               2669    7.2292   NaN        C
# 81               0      0             345767    9.0000   NaN        S
# 113              0      0             324669    8.0500   NaN        S
# 213              0      0          A/5 21174    7.2500   NaN        S
# 226              0      0            PP 4348    9.3500   NaN        S
# 244              0      0  STON/O 2. 3101275    7.1250   NaN        S
# 288              0      0             349206    7.8958   NaN        S
# 321              0      0          A/5 21172    7.2500   NaN        S
# 374              0      0           PC 17760  135.6333   NaN        C
# 396              0      0             350052    7.7958   NaN        S
# 479              0      0             350060    7.5208   NaN        S
# 522              0      0             349252    7.8958   NaN        S
# 554              0      0               2620    7.2250   NaN        C
# 589              0      0              14973    8.0500   NaN        S
# 1018             0      0             350045    7.7958   NaN        S
# 1039             0      0        SC/A4 23568    8.0500   NaN        S
# 1171             0      0        W./C. 14260   10.5000   NaN        S
# 1203             0      0               2658    7.2250   NaN        C
# 1211             2      0         C.A. 31029   31.5000   NaN        S
# 1290             0      0             347065    7.7750   NaN        S

# %% [markdown]
# # Summary statistic

# %%
df.describe()
# Out:
#           Survived       Pclass          Age        SibSp        Parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean     -0.058060     2.294882    29.881138     0.498854     0.385027
# std       0.760044     0.837836    14.413493     1.041658     0.865560
# min      -1.000000     1.000000     0.170000     0.000000     0.000000
# 25%      -1.000000     2.000000    21.000000     0.000000     0.000000
# 50%       0.000000     3.000000    28.000000     0.000000     0.000000
# 75%       1.000000     3.000000    39.000000     1.000000     0.000000
# max       1.000000     3.000000    80.000000     8.000000     9.000000
#
#               Fare
# count  1308.000000
# mean     33.295479
# std      51.758668
# min       0.000000
# 25%       7.895800
# 50%      14.454200
# 75%      31.275000
# max     512.329200

# %%
print(df.Age.median())
print(df.Age.quantile(.75))
print(f'variance = {df.Age.var()}')
print(f'Standart Deviation = {df.Age.std()}')
# Out:
# 28.0
# 39.0
# variance = 207.74878655136447
# Standart Deviation = 14.413493211271321

# %%
df.Name.unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina', ..., 'Saether, Mr. Simon Sivertsen',
#        'Ware, Mr. Frederick', 'Peter, Master. Michael J'], dtype=object)

# %%
df.Age.plot(kind='box')

# %% [markdown]
# # Categorical Fields - Text

# %%
df.describe(include='all')
# Out:
#            Survived       Pclass              Name   Sex          Age  \
# count   1309.000000  1309.000000              1309  1309  1046.000000
# unique          NaN          NaN              1307     2          NaN
# top             NaN          NaN  Kelly, Mr. James  male          NaN
# freq            NaN          NaN                 2   843          NaN
# mean      -0.058060     2.294882               NaN   NaN    29.881138
# std        0.760044     0.837836               NaN   NaN    14.413493
# min       -1.000000     1.000000               NaN   NaN     0.170000
# 25%       -1.000000     2.000000               NaN   NaN    21.000000
# 50%        0.000000     3.000000               NaN   NaN    28.000000
# 75%        1.000000     3.000000               NaN   NaN    39.000000
# max        1.000000     3.000000               NaN   NaN    80.000000
#
#               SibSp        Parch    Ticket         Fare        Cabin Embarked
# count   1309.000000  1309.000000      1309  1308.000000          295     1307
# unique          NaN          NaN       929          NaN          186        3
# top             NaN          NaN  CA. 2343          NaN  C23 C25 C27        S
# freq            NaN          NaN        11          NaN            6      914
# mean       0.498854     0.385027       NaN    33.295479          NaN      NaN
# std        1.041658     0.865560       NaN    51.758668          NaN      NaN
# min        0.000000     0.000000       NaN     0.000000          NaN      NaN
# 25%        0.000000     0.000000       NaN     7.895800          NaN      NaN
# 50%        0.000000     0.000000       NaN    14.454200          NaN      NaN
# 75%        1.000000     0.000000       NaN    31.275000          NaN      NaN
# max        8.000000     9.000000       NaN   512.329200          NaN      NaN

# %%
df.Sex.value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts(normalize=True)
# Out:
# male      0.644003
# female    0.355997
# Name: Sex, dtype: float64

# %%
a = df[df.Survived == 1].Pclass.value_counts()
a
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
a.plot(kind='bar')

# %%
df.Age.plot(kind='kde')

# %%
df.Age.plot(kind='hist')
